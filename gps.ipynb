# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
file = 'dataset/GPS_Kosuke_san_train_walk.csv'
dataframe = pd.read_csv(file)

# %%
dataframe.head()
# Out:
#            time   latitude   longitude  accuracy  speed
# 0  1.557933e+09  35.649103  139.705734  9.724000    0.0
# 1  1.557933e+09  35.649103  139.705732  7.559210    0.0
# 2  1.557933e+09  35.649102  139.705729  7.077673    0.0
# 3  1.557933e+09  35.649101  139.705727  7.019443    0.0
# 4  1.557933e+09  35.649103  139.705727  6.997450    0.0

# %%
df = pd.read_csv(file)
dataset = df.values
time = dataset[:, 0]
latitude = dataset[:, 1]
longitude = dataset[:, 2]


from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0
speed_array = []
for i in range (len(time) - 1  ):

    lat1 = radians(latitude[i])
    lon1 = radians(longitude[i])
    lat2 = radians(latitude[i+1])
    lon2 = radians(longitude[i+1])
    tim1 = time[i]
    tim2 = time[i+1]

    dlon = lon2 - lon1
    dlat = lat2 - lat1
    dtim = tim2 - tim1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    # speed in m/s
    speed = ((distance * 1000)/dtim)
    speed_array.append(speed)
speed = np.array(speed_array)
# Out:
# /home/abhijeet/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: divide by zero encountered in double_scalars

# %%
len(speed)
# Out:
# 12584

# %%
len(dataframe)
# Out:
# 12585

# %%
dataframe['speed_new'] = 0

# %%
dataframe['speed_new'][1:] =speed
# Out:
# /home/abhijeet/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataframe
# Out:
#                time   latitude   longitude   accuracy  speed  speed_new
# 0      1.557933e+09  35.649103  139.705734   9.724000   0.00   0.000000
# 1      1.557933e+09  35.649103  139.705732   7.559210   0.00   0.035277
# 2      1.557933e+09  35.649102  139.705729   7.077673   0.00   0.048132
# 3      1.557933e+09  35.649101  139.705727   7.019443   0.00   0.030494
# 4      1.557933e+09  35.649103  139.705727   6.997450   0.00   0.038780
# 5      1.557933e+09  35.649103  139.705726   7.047399   0.00   0.016950
# 6      1.557933e+09  35.649103  139.705727   7.050053   0.00   0.014835
# 7      1.557933e+09  35.649102  139.705728   7.605185   0.00   0.006827
# 8      1.557933e+09  35.649105  139.705729   7.254734   0.00   0.046007
# 9      1.557933e+09  35.649106  139.705729   7.220153   0.00   0.020565
# 10     1.557933e+09  35.649106  139.705729   7.071262   0.00   0.005540
# 11     1.557933e+09  35.649106  139.705728   7.059093   0.00   0.009085
# ...

# %%
plt.plot(speed)

# %%
x = 1
start = x
end = x + 5
plt.scatter(latitude[start : end], longitude[start : end])
